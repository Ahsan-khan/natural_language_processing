# %% [markdown]
# # Entity Resolution on Unlabeled Text Data

# %% [markdown]
# #### By Ahsan Khan

# %%
# Set up Library imports

import pandas as pd
import re
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from sklearn.metrics import jaccard_similarity_score

# %%
# Read csv files into Pandas dataframes

entities_df = pd.read_csv('C:\\Users\\Ahsan\\Desktop\\Capstone\\prototype\\Random entity test 1.csv')

targets_df = pd.read_csv('C:\\Users\\Ahsan\\Desktop\\Capstone\\prototype\All targets.csv')

# deep copy
intact_entities_df = entities_df.copy()
intact_targets_df = targets_df.copy()

# %%
entities_df
# Out:
#                                       Random entities
# 0   JP MORGAN BANK (IRELAND) PLC AS TRUSTEE OF BLA...
# 1   JP MORGAN BANK (IRELAND) PLC AS TRUSTEE OF BLA...
# 2   JP MORGAN BANK (IRELAND) PLC AS TRUSTEE OF BLA...
# 3   JP MORGAN BANK (IRELAND) PLC AS TRUSTEE OF BLA...
# 4   JP MORGAN BANK (IRELAND) PLC AS TRUSTEE OF BLA...
# 5   JP MORGAN BANK (IRELAND) PLC AS TRUSTEE OF BLA...
# 6   JP MORGAN BANK (IRELAND) PLC AS TRUSTEE OF BLA...
# 7   JP MORGAN BANK (IRELAND) PLC AS TRUSTEE OF BLA...
# 8   JP MORGAN BANK (IRELAND) PLC AS TRUSTEE OF BLA...
# 9   JP MORGAN BANK (IRELAND) PLC AS TRUSTEE OF BLA...
# 10  COMMINGLED PENSION TRUST FUND (INTERMEDIATE PU...
# 11  COMMINGLED PENSION TRUST FUND (INTERNATIONAL E...
# 12  Commingled Pension Trust Fund (Large Cap Growt...
# 13  COMMINGLED PENSION TRUST FUND (PUBLIC BOND) OF...
# 14  Commingled Pension Trust Fund (Stable Asset In...
# 15  COMMINGLED PENSION TRUST FUND (STABLE INCOME B...
# 16  COMMINGLED PENSION TRUST FUND (SYSTEMATIC ALPH...
# 17  Commingled Pension Trust Fund (U.S. Active Cor...
# 18  Commingled Pension Trust Fund (U.S. Active Val...
# 19  COMMINGLED PENSION TRUST FUND (U.S. REAL ESTAT...
# 20  Commingled Pension Trust Fund (U.S. Smartlndex...
# 21                     DEUTSCHE MORGAN GREN AUS L-SYD
# 22  DEUTSCHE MORGAN GRENFELL (C.I.) LIMITED FKA: M...
# 23             DEUTSCHE MORGAN GRENFELL AUSTRALIA LTD
# 24                           J P MORGAN AUST LTD MELB
# 25                          J P MORGAN CANADA-TOR ONT
# 26                          J P MORGAN EUROPE LTD LDN
# 27                          J P MORGAN INV MGT INC-NY
# 28                         J P MORGAN SEC CAN INC-TOR
# 29                          J P Morgan Securities LLC
# ..                                                ...
# 38                         J.P. MORGAN EUROPE LIMITED
# 39  J.P. MORGAN EXCHANGE-TRADED FUND - JPMORGAN CO...
# 40                J.P. MORGAN INV MGT AAF SEL FD(USA)
# 41                            J.P. MORGAN INV MGT-USA
# 42              J.P. MORGAN INVESTMENT MANAGEMENT CO.
# 43             J.P. MORGAN INVESTMENT MANAGEMENT INC.
# 44             J.P. MORGAN INVESTMENT MANAGEMENT INC.
# 45  J.P. MORGAN INVESTMENT MANAGEMENT INC. AS AGEN...
# 46  J.P. Morgan Investment Management Inc. As Agen...
# 47  J.P. MORGAN INVESTMENT MANAGEMENT INC. AS AGEN...
# 48                        J.P. MORGAN INVESTMENT MGMT
# 49                        J.P. MORGAN INVESTMENT MGMT
# 50                        J.P. MORGAN INVESTMENT MGMT
# 51                        J.P. MORGAN INVESTMENT MGMT
# 52                        J.P. MORGAN INVESTMENT MGMT
# 53                        J.P. MORGAN INVESTMENT MGMT
# 54                        J.P. MORGAN INVESTMENT MGMT
# 55                        J.P. MORGAN INVESTMENT MGMT
# 56                        J.P. MORGAN INVESTMENT MGMT
# 57                     J.P. MORGAN INVESTMENT MGMT IN
# 58                     J.P. MORGAN INVESTMENT MGMT IN
# 59                     J.P. MORGAN INVESTMENT MGMT IN
# 60                     J.P. MORGAN INVESTMENT MGMT IN
# 61                     J.P. MORGAN INVESTMENT MGMT IN
# 62                     J.P. MORGAN INVESTMENT MGMT IN
# 63                         J.P. MORGAN INVST MGMT-NYC
# 64                                     MORGAN STANLEY
# 65                                     MORGAN STANLEY
# 66                                     MORGAN STANLEY
# 67                                     MORGAN STANLEY
#
# [68 rows x 1 columns]

# %%
targets_df
# Out:
#                                         Target
# 0              Blackrock Advisors (UK) Limited
# 1         BlackRock Financial Management, Inc.
# 2                Commingled Pension Trust Fund
# 3                Commingled Pension Trust Fund
# 4                Commingled Pension Trust Fund
# 5                Commingled Pension Trust Fund
# 6                Commingled Pension Trust Fund
# 7                Commingled Pension Trust Fund
# 8                Commingled Pension Trust Fund
# 9                Commingled Pension Trust Fund
# 10               Commingled Pension Trust Fund
# 11               Commingled Pension Trust Fund
# 12               Commingled Pension Trust Fund
# 13               Commingled Pension Trust Fund
# 14               Commingled Pension Trust Fund
# 15               Commingled Pension Trust Fund
# 16               Commingled Pension Trust Fund
# 17               Commingled Pension Trust Fund
# 18     J.P. Morgan Investment Management, Inc.
# 19     J.P. Morgan Investment Management, Inc.
# 20     J.P. Morgan Investment Management, Inc.
# 21     J.P. Morgan Investment Management, Inc.
# 22     J.P. Morgan Investment Management, Inc.
# 23     J.P. Morgan Investment Management, Inc.
# 24     J.P. Morgan Investment Management, Inc.
# 25     J.P. Morgan Investment Management, Inc.
# 26     J.P. Morgan Investment Management, Inc.
# 27     J.P. Morgan Investment Management, Inc.
# 28     J.P. Morgan Investment Management, Inc.
# 29     J.P. Morgan Investment Management, Inc.
# ..                                         ...
# 342                   Morgan Stanley & Co. LLC
# 343                   Morgan Stanley & Co. LLC
# 344                   Morgan Stanley & Co. LLC
# 345                   Morgan Stanley & Co. LLC
# 346            Morgan Stanley (Jersey) Limited
# 347                Morgan Stanley Asia Limited
# 348                Morgan Stanley Asia Limited
# 349                Morgan Stanley Asia Limited
# 350                Morgan Stanley Asia Limited
# 351                Morgan Stanley Asia Limited
# 352                Morgan Stanley Asia Limited
# 353                Morgan Stanley Asia Limited
# 354  Morgan Stanley Investment Management Inc.
# 355  Morgan Stanley Investment Management Inc.
# 356  Morgan Stanley Investment Management Inc.
# 357                             Morgan Stanley
# 358                             Morgan Stanley
# 359                             Morgan Stanley
# 360                             Morgan Stanley
# 361                             Morgan Stanley
# 362                             Morgan Stanley
# 363                             Morgan Stanley
# 364                             Morgan Stanley
# 365                   Morgan Stanley & Co. LLC
# 366                   Morgan Stanley & Co. LLC
# 367     Morgan Stanley & Co. International plc
# 368     Morgan Stanley & Co. International plc
# 369     Morgan Stanley & Co. International plc
# 370     Morgan Stanley & Co. International plc
# 371     Morgan Stanley & Co. International plc
#
# [372 rows x 1 columns]

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# In the preprocessing state we are removing all punctuation, numbers and converting all text to lowercase. This will ensure uniformity in the corpus and all incoming entities

# %%
# Remove punctuation and numbers, and convert to lower case 

def preprocess(df):
    df.iloc[:,0] = df.iloc[:,0].apply(lambda x : str.lower(x)) # lower case
    df.iloc[:,0] = df.iloc[:,0].apply\
            (lambda x : " ".join(re.findall('[\w]+',x))) # remove punc, nums 
    return df

# %% [markdown]
# ### Generating 3 character tokens (markov N-grams)

# %%
# A function for generating markov tokens 

remove_spaces = lambda s : "".join(s.split())

def split_3_char(s):
    if len(s) == 3:
        return s
    return s[:3] + ' ' + split_3_char(s[1:])

# %%
# Generating markov tokens of our dataframe

def tokenize_all(df):
    l = list(df.iloc[:,0])
    Tokens = []
    for w in l:
        w = remove_spaces(w)
        tok = split_3_char(w)
        Tokens.append(tok)
    return Tokens

# %% [markdown]
# ### Checking jaccard similarty (scraped)

# %% [markdown]
# It was found that Jaccard similarity was not giving us the best match even though it is known best for text data. Say we have the token "ele" 3 repeat times in the title of an entity. Jaccard similarity will count it as just 1 "ele" and hence defeat the purpose. Cosine similarity will give us a better matching.

# %%
# jaccard similartiy function

def get_jaccard_sim(str1, str2): 
    a = set(str1.split()) 
    b = set(str2.split())
    c = a.intersection(b)
    return float(len(c)) / (len(a) + len(b) - len(c))

# %%
# Running our functions on data

entities_df = preprocess(entities_df)
targets_df = preprocess(targets_df)
ent_corpus = tokenize_all(entities_df)
targ_corpus = tokenize_all(targets_df)
ent_size = len(ent_corpus)
corpus_ent_targ = ent_corpus + targ_corpus # A giant corpus containing both entities and targets markov tokens.

# %%
ent_corpus
# Out:
# ['jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc lca cas ast str tru rus ust ste tee eeo eof ofb fbl bla lac ack ckr kro roc ock ckl kli lia iab abi bil ili lit ity tym yma mat atc tch chi hin ing ngf gfu fun und nds dsl sle lev eve ver era rag age ged eds dst stl tlg',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc lca cas ast str tru rus ust ste tee eeo eof ofb fbl bla lac ack ckr kro roc ock ckl kli lia iab abi bil ili lit ity tym yma mat atc tch chi hin ing ngf gfu fun und nds dsl sle lev eve ver era rag age ged eds dst stl tlg',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc lca cas ast str tru rus ust ste tee eeo eof ofb fbl bla lac ack ckr kro roc ock ckl kli lia iab abi bil ili lit ity tym yma mat atc tch chi hin ing ngf gfu fun und nds dsl sle lev eve ver era rag age ged eds dst stl tlg',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc lca cas ast str tru rus ust ste tee eeo eof ofb fbl bla lac ack ckr kro roc ock ckl kli lia iab abi bil ili lit ity tym yma mat atc tch chi hin ing ngf gfu fun und nds dsl sle lev eve ver era rag age ged eds dst stl tlg',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc lca cas ast str tru rus ust ste tee eeo eof ofb fbl bla lac ack ckr kro roc ock ckl kli lia iab abi bil ili lit ity tym yma mat atc tch chi hin ing ngf gfu fun und nds dsl sle lev eve ver era rag age ged eds dst stl tlg',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc lca cas ast str tru rus ust ste tee eeo eof ofb fbl bla lac ack ckr kro roc ock ckl kli lia iab abi bil ili lit ity tym yma mat atc tch chi hin ing ngf gfu fun und nds dsl sle lev eve ver era rag age ged eds dst stl tlg',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc lca cas ast str tru rus ust ste tee eeo eof ofb fbl bla lac ack ckr kro roc ock ckl kli lia iab abi bil ili lit ity tym yma mat atc tch chi hin ing ngf gfu fun und nds dsl sle lev eve ver era rag age ged eds dst stl tlg',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc lca cas ast str tru rus ust ste tee eeo eof ofb fbl bla lac ack ckr kro roc ock ckl kli lia iab abi bil ili lif ify fym yma mat atc tch chi hin ing ngf gfu fun und nds dsl sle lev eve ver era rag age ged eds dst stl tlg',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc lca cas ast str tru rus ust ste tee eeo eof ofb fbl bla lac ack ckr kro roc ock ckl kli lia iab abi bil ili lit ity tym yma mat atc tch chi hin ing ngf gfu fun und nds dsl sle lev eve ver era rag age ged eds dst stl tlg',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc lca cas ast str tru rus ust ste tee eeo eof ofb fbl bla lac ack ckr kro roc ock ckl kli lia iab abi bil ili lit ity tym yma mat atc tch chi hin ing ngf gfu fun und nds dsl sle lev eve ver era rag age ged eds dst stl tlg',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und ndi din int nte ter erm rme med edi dia iat ate tep epu pub ubl bli lic icb cbo bon ond ndo dof ofj fjp jpm pmo mor org rga gan anc nch cha has ase seb eba ban ank nkn kna',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und ndi din int nte ter ern rna nat ati tio ion ona nal ale leq equ qui uit ity tyo yof ofj fjp jpm pmo mor org rga gan anc nch cha has ase seb eba ban ank nkn kna',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und ndl dla lar arg rge gec eca cap apg pgr gro row owt wth tho hof ofj fjp jpm pmo mor org rga gan anc nch cha has ase seb eba ban ank nkn kna',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und ndp dpu pub ubl bli lic icb cbo bon ond ndo dof ofj fjp jpm pmo mor org rga gan anc nch cha has ase seb eba ban ank nkn kna',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und nds dst sta tab abl ble lea eas ass sse set eti tin inc nco com ome meo eof ofj fjp jpm pmo mor org rga gan anc nch cha has ase seb eba ban ank nkn kna',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und nds dst sta tab abl ble lei ein inc nco com ome meb ebo bon ond ndo dof ofj fjp jpm pmo mor org rga gan anc nch cha has ase seb eba ban ank nkn kna',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und nds dsy sys yst ste tem ema mat ati tic ica cal alp lph pha haj ajp jpm pmo mor org rga gan anc nch cha has ase seb eba ban ank nkn kna',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und ndu dus usa sac act cti tiv ive vec eco cor ore ree eeq equ qui uit ity tyo yof ofj fjp jpm pmo mor org rga gan anc nch cha has ase seb eba ban ank nkn kna',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und ndu dus usa sac act cti tiv ive vev eva val alu lue ueo eof ofj fjp jpm pmo mor org rga gan anc nch cha has ase seb eba ban ank nkn kna',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und ndu dus usr sre rea eal ale les est sta tat ate tes ese sec ecu cur uri rit iti tie ies eso sof ofj fjp jpm pmo mor org rga gan anc nch cha has ase seb eba ban ank nkn kna',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und ndu dus uss ssm sma mar art rtl tln lnd nde dex exo xof ofj fjp jpm pmo mor org rga gan anc nch cha has ase seb eba ban ank nkn kna',
#  'deu eut uts tsc sch che hem emo mor org rga gan ang ngr gre ren ena nau aus usl sls lsy syd',
#  'deu eut uts tsc sch che hem emo mor org rga gan ang ngr gre ren enf nfe fel ell llc lci cil ili lim imi mit ite ted edf dfk fka kam amo mor org rga gan ang ngr gre ren enf nfe fel ell llc lci cil ili lim imi mit ite ted',
#  'deu eut uts tsc sch che hem emo mor org rga gan ang ngr gre ren enf nfe fel ell lla lau aus ust str tra ral ali lia ial alt ltd',
#  'jpm pmo mor org rga gan ana nau aus ust stl tlt ltd tdm dme mel elb',
#  'jpm pmo mor org rga gan anc nca can ana nad ada dat ato tor oro ron ont',
#  'jpm pmo mor org rga gan ane neu eur uro rop ope pel elt ltd tdl dld ldn',
#  'jpm pmo mor org rga gan ani nin inv nvm vmg mgt gti tin inc ncn cny',
#  'jpm pmo mor org rga gan ans nse sec ecc cca can ani nin inc nct cto tor',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ani nin inv nvm vmg mgm gmt mti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nvm vmg mgm gmt mti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nvm vmg mgm gmt mti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nvm vmg mgm gmt mti tin inc',
#  'jpm pmo mor org rga gan anc nch cha has ase sec eco com omm mme mer erc rci cia ial alm lmo mor ort rtg tga gag age ges ese sec ecu cur uri rit iti tie ies est str tru rus ust st2 t20 201 015 15u 5ue ues',
#  'jpm pmo mor org rga gan anc nch cha has ase sec eco com omm mme mer erc rci cia ial alm lmo mor ort rtg tga gag age ges ese sec ecu cur uri rit iti tie ies est str tru rus ust st2 t20 201 015 15u 5ue ues',
#  'jpm pmo mor org rga gan anc nch cha has ase sec eco com omm mme mer erc rci cia ial alm lmo mor ort rtg tga gag age ges ese sec ecu cur uri rit iti tie ies est str tru rus ust st2 t20 201 015 15u 5ue ues',
#  'jpm pmo mor org rga gan ane neu eur uro rop ope pel eli lim imi mit ite ted',
#  'jpm pmo mor org rga gan ane nex exc xch cha han ang nge get etr tra rad ade ded edf dfu fun und ndj djp jpm pmo mor org rga gan anc nco cor orp rpo por ora rat ate teb ebo bon ond ndr dre res ese sea ear arc rch che hen enh nha han anc nce ced ede det etf',
#  'jpm pmo mor org rga gan ani nin inv nvm vmg mgt gta taa aaf afs fse sel elf lfd fdu dus usa',
#  'jpm pmo mor org rga gan ani nin inv nvm vmg mgt gtu tus usa',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent ntc tco',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc nca cas asa sag age gen ent ntf tfo for ors rse sel ele lec ect ctf tfu fun und nds dsu sus usa',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc nca cas asa sag age gen ent ntf tfo for ors rse sel ele lec ect ctf tfu fun und nds dsu sus usa',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc nca cas asa sag age gen ent ntf tfo for ors rse sel ele lec ect ctf tfu fun und nds dsu sus usa',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt mti tin',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt mti tin',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt mti tin',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt mti tin',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt mti tin',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt mti tin',
#  'jpm pmo mor org rga gan ani nin inv nvs vst stm tmg mgm gmt mtn tny nyc',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley']

# %%
# Main corpus

corpus_ent_targ
# Out:
# ['jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc lca cas ast str tru rus ust ste tee eeo eof ofb fbl bla lac ack ckr kro roc ock ckl kli lia iab abi bil ili lit ity tym yma mat atc tch chi hin ing ngf gfu fun und nds dsl sle lev eve ver era rag age ged eds dst stl tlg',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc lca cas ast str tru rus ust ste tee eeo eof ofb fbl bla lac ack ckr kro roc ock ckl kli lia iab abi bil ili lit ity tym yma mat atc tch chi hin ing ngf gfu fun und nds dsl sle lev eve ver era rag age ged eds dst stl tlg',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc lca cas ast str tru rus ust ste tee eeo eof ofb fbl bla lac ack ckr kro roc ock ckl kli lia iab abi bil ili lit ity tym yma mat atc tch chi hin ing ngf gfu fun und nds dsl sle lev eve ver era rag age ged eds dst stl tlg',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc lca cas ast str tru rus ust ste tee eeo eof ofb fbl bla lac ack ckr kro roc ock ckl kli lia iab abi bil ili lit ity tym yma mat atc tch chi hin ing ngf gfu fun und nds dsl sle lev eve ver era rag age ged eds dst stl tlg',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc lca cas ast str tru rus ust ste tee eeo eof ofb fbl bla lac ack ckr kro roc ock ckl kli lia iab abi bil ili lit ity tym yma mat atc tch chi hin ing ngf gfu fun und nds dsl sle lev eve ver era rag age ged eds dst stl tlg',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc lca cas ast str tru rus ust ste tee eeo eof ofb fbl bla lac ack ckr kro roc ock ckl kli lia iab abi bil ili lit ity tym yma mat atc tch chi hin ing ngf gfu fun und nds dsl sle lev eve ver era rag age ged eds dst stl tlg',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc lca cas ast str tru rus ust ste tee eeo eof ofb fbl bla lac ack ckr kro roc ock ckl kli lia iab abi bil ili lit ity tym yma mat atc tch chi hin ing ngf gfu fun und nds dsl sle lev eve ver era rag age ged eds dst stl tlg',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc lca cas ast str tru rus ust ste tee eeo eof ofb fbl bla lac ack ckr kro roc ock ckl kli lia iab abi bil ili lif ify fym yma mat atc tch chi hin ing ngf gfu fun und nds dsl sle lev eve ver era rag age ged eds dst stl tlg',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc lca cas ast str tru rus ust ste tee eeo eof ofb fbl bla lac ack ckr kro roc ock ckl kli lia iab abi bil ili lit ity tym yma mat atc tch chi hin ing ngf gfu fun und nds dsl sle lev eve ver era rag age ged eds dst stl tlg',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc lca cas ast str tru rus ust ste tee eeo eof ofb fbl bla lac ack ckr kro roc ock ckl kli lia iab abi bil ili lit ity tym yma mat atc tch chi hin ing ngf gfu fun und nds dsl sle lev eve ver era rag age ged eds dst stl tlg',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und ndi din int nte ter erm rme med edi dia iat ate tep epu pub ubl bli lic icb cbo bon ond ndo dof ofj fjp jpm pmo mor org rga gan anc nch cha has ase seb eba ban ank nkn kna',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und ndi din int nte ter ern rna nat ati tio ion ona nal ale leq equ qui uit ity tyo yof ofj fjp jpm pmo mor org rga gan anc nch cha has ase seb eba ban ank nkn kna',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und ndl dla lar arg rge gec eca cap apg pgr gro row owt wth tho hof ofj fjp jpm pmo mor org rga gan anc nch cha has ase seb eba ban ank nkn kna',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und ndp dpu pub ubl bli lic icb cbo bon ond ndo dof ofj fjp jpm pmo mor org rga gan anc nch cha has ase seb eba ban ank nkn kna',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und nds dst sta tab abl ble lea eas ass sse set eti tin inc nco com ome meo eof ofj fjp jpm pmo mor org rga gan anc nch cha has ase seb eba ban ank nkn kna',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und nds dst sta tab abl ble lei ein inc nco com ome meb ebo bon ond ndo dof ofj fjp jpm pmo mor org rga gan anc nch cha has ase seb eba ban ank nkn kna',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und nds dsy sys yst ste tem ema mat ati tic ica cal alp lph pha haj ajp jpm pmo mor org rga gan anc nch cha has ase seb eba ban ank nkn kna',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und ndu dus usa sac act cti tiv ive vec eco cor ore ree eeq equ qui uit ity tyo yof ofj fjp jpm pmo mor org rga gan anc nch cha has ase seb eba ban ank nkn kna',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und ndu dus usa sac act cti tiv ive vev eva val alu lue ueo eof ofj fjp jpm pmo mor org rga gan anc nch cha has ase seb eba ban ank nkn kna',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und ndu dus usr sre rea eal ale les est sta tat ate tes ese sec ecu cur uri rit iti tie ies eso sof ofj fjp jpm pmo mor org rga gan anc nch cha has ase seb eba ban ank nkn kna',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und ndu dus uss ssm sma mar art rtl tln lnd nde dex exo xof ofj fjp jpm pmo mor org rga gan anc nch cha has ase seb eba ban ank nkn kna',
#  'deu eut uts tsc sch che hem emo mor org rga gan ang ngr gre ren ena nau aus usl sls lsy syd',
#  'deu eut uts tsc sch che hem emo mor org rga gan ang ngr gre ren enf nfe fel ell llc lci cil ili lim imi mit ite ted edf dfk fka kam amo mor org rga gan ang ngr gre ren enf nfe fel ell llc lci cil ili lim imi mit ite ted',
#  'deu eut uts tsc sch che hem emo mor org rga gan ang ngr gre ren enf nfe fel ell lla lau aus ust str tra ral ali lia ial alt ltd',
#  'jpm pmo mor org rga gan ana nau aus ust stl tlt ltd tdm dme mel elb',
#  'jpm pmo mor org rga gan anc nca can ana nad ada dat ato tor oro ron ont',
#  'jpm pmo mor org rga gan ane neu eur uro rop ope pel elt ltd tdl dld ldn',
#  'jpm pmo mor org rga gan ani nin inv nvm vmg mgt gti tin inc ncn cny',
#  'jpm pmo mor org rga gan ans nse sec ecc cca can ani nin inc nct cto tor',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ani nin inv nvm vmg mgm gmt mti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nvm vmg mgm gmt mti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nvm vmg mgm gmt mti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nvm vmg mgm gmt mti tin inc',
#  'jpm pmo mor org rga gan anc nch cha has ase sec eco com omm mme mer erc rci cia ial alm lmo mor ort rtg tga gag age ges ese sec ecu cur uri rit iti tie ies est str tru rus ust st2 t20 201 015 15u 5ue ues',
#  'jpm pmo mor org rga gan anc nch cha has ase sec eco com omm mme mer erc rci cia ial alm lmo mor ort rtg tga gag age ges ese sec ecu cur uri rit iti tie ies est str tru rus ust st2 t20 201 015 15u 5ue ues',
#  'jpm pmo mor org rga gan anc nch cha has ase sec eco com omm mme mer erc rci cia ial alm lmo mor ort rtg tga gag age ges ese sec ecu cur uri rit iti tie ies est str tru rus ust st2 t20 201 015 15u 5ue ues',
#  'jpm pmo mor org rga gan ane neu eur uro rop ope pel eli lim imi mit ite ted',
#  'jpm pmo mor org rga gan ane nex exc xch cha han ang nge get etr tra rad ade ded edf dfu fun und ndj djp jpm pmo mor org rga gan anc nco cor orp rpo por ora rat ate teb ebo bon ond ndr dre res ese sea ear arc rch che hen enh nha han anc nce ced ede det etf',
#  'jpm pmo mor org rga gan ani nin inv nvm vmg mgt gta taa aaf afs fse sel elf lfd fdu dus usa',
#  'jpm pmo mor org rga gan ani nin inv nvm vmg mgt gtu tus usa',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent ntc tco',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc nca cas asa sag age gen ent ntf tfo for ors rse sel ele lec ect ctf tfu fun und nds dsu sus usa',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc nca cas asa sag age gen ent ntf tfo for ors rse sel ele lec ect ctf tfu fun und nds dsu sus usa',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc nca cas asa sag age gen ent ntf tfo for ors rse sel ele lec ect ctf tfu fun und nds dsu sus usa',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt mti tin',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt mti tin',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt mti tin',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt mti tin',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt mti tin',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tmg mgm gmt mti tin',
#  'jpm pmo mor org rga gan ani nin inv nvs vst stm tmg mgm gmt mtn tny nyc',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'bla lac ack ckr kro roc ock cka kad adv dvi vis iso sor ors rsu suk ukl kli lim imi mit ite ted',
#  'bla lac ack ckr kro roc ock ckf kfi fin ina nan anc nci cia ial alm lma man ana nag age gem eme men ent nti tin inc',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esp spl plc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esp spl plc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esp spl plc',
#  'jpm pmo mor org rga gan anw nwh whi hit ite tef efr fri ria iar ars rsl sll llc',
#  'jpm pmo mor org rga gan anw nwh whi hit ite tef efr fri ria iar ars rsl sll llc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ana nas ass sse set etm tma man ana nag age gem eme men ent ntu tuk ukl kli lim imi mit ite ted',
#  'jpm pmo mor org rga gan ana nas ass sse set etm tma man ana nag age gem eme men ent ntu tuk ukl kli lim imi mit ite ted',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpi pic',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpi pic',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpi pic',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpi pic',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpi pic',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpi pic',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpi pic',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpi pic',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpi pic',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal al1 l1t 1tr tru rus ust st2 t20 201 017 17h 7h1',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal al1 l1t 1tr tru rus ust st2 t20 201 017 17h 7h1',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal al1 l1t 1tr tru rus ust st2 t20 201 017 17h 7h1',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal al1 l1t 1tr tru rus ust st2 t20 201 017 17h 7hr hr2',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal al1 l1t 1tr tru rus ust st2 t20 201 017 17h 7hr hr2',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal al1 l1t 1tr tru rus ust st2 t20 201 017 17h 7hr hr2',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal al1 l1t 1tr tru rus ust st2 t20 201 018 18h 8h3',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal al1 l1t 1tr tru rus ust st2 t20 201 018 18h 8h3',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal al1 l1t 1tr tru rus ust st2 t20 201 018 18h 8h3',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal al1 l1t 1tr tru rus ust st2 t20 201 018 18h 8h3',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal al1 l1t 1tr tru rus ust st2 t20 201 018 18h 8h3',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal al1 l1t 1tr tru rus ust st2 t20 201 018 18h 8h3',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal al1 l1t 1tr tru rus ust st2 t20 201 018 18l 8l1',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal al1 l1t 1tr tru rus ust st2 t20 201 018 18l 8l1',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal als lse ser erv rvi vic ice ces esl sll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal als lse ser erv rvi vic ice ces esl sll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal als lse ser erv rvi vic ice ces esl sll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal als lse ser erv rvi vic ice ces esl sll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal als lse ser erv rvi vic ice ces esl sll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal als lse ser erv rvi vic ice ces esl sll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc ycr cre red edi dit itp tpr pro rod odu duc uct cts tsl slt ltd',
#  'mor org rga gan ans nst sta tan anl nle ley eyd yde def efi fin ine ned edc dco con ont ntr tri rib ibu but uti tio ion onm nma mas ast ste ter ert rtr tru rus ust',
#  'mor org rga gan ans nst sta tan anl nle ley eyd yde def efi fin ine ned edc dco con ont ntr tri rib ibu but uti tio ion onm nma mas ast ste ter ert rtr tru rus ust',
#  'mor org rga gan ans nst sta tan anl nle ley eyd yde def efi fin ine ned edc dco con ont ntr tri rib ibu but uti tio ion onm nma mas ast ste ter ert rtr tru rus ust',
#  'mor org rga gan ans nst sta tan anl nle ley eyd yde def efi fin ine ned edc dco con ont ntr tri rib ibu but uti tio ion onm nma mas ast ste ter ert rtr tru rus ust',
#  'mor org rga gan ans nst sta tan anl nle ley eyd yde def efi fin ine ned edc dco con ont ntr tri rib ibu but uti tio ion onm nma mas ast ste ter ert rtr tru rus ust',
#  'mor org rga gan ans nst sta tan anl nle ley eyd yde def efi fin ine ned edc dco con ont ntr tri rib ibu but uti tio ion onm nma mas ast ste ter ert rtr tru rus ust',
#  'mor org rga gan ans nst sta tan anl nle ley eyd yde def efi fin ine ned edc dco con ont ntr tri rib ibu but uti tio ion onm nma mas ast ste ter ert rtr tru rus ust',
#  'mor orp rpa pan ans nst sta tan anl nle ley eyd yde def efi fin ine ned edc dco con ont ntr tri rib ibu but uti tio ion onm nma mas ast ste ter ert rtr tru rus ust',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan anm nmo mor ort rtg tga gag age gea eac acq cqu qui uis isi sit iti tio ion onc nco cor orp',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esa sau aus ust str tra ral ali lia ial ali lim imi mit ite ted',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esa sau aus ust str tra ral ali lia ial ali lim imi mit ite ted',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esa sau aus ust str tra ral ali lia ial ali lim imi mit ite ted',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esa sau aus ust str tra ral ali lia ial ali lim imi mit ite ted',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esa sau aus ust str tra ral ali lia ial ali lim imi mit ite ted',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esa sau aus ust str tra ral ali lia ial ali lim imi mit ite ted',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esc sca can ana nad ada dai ain inc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esp spl plc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esu sul ulc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyb yba ban ank nko kof ofa fam ame mer eri ric ica cam ame mer err rri ril ill lll lly lyn ync nch cht htr tru rus ust st2 t20 201 015 15c 5c2 c26',
#  'mor org rga gan ans nst sta tan anl nle ley eyb yba ban ank nkn kna',
#  'mor org rga gan ans nst sta tan anl nle ley eyb yba ban ank nkn kna',
#  'mor org rga gan ans nst sta tan anl nle ley eyb yba ban ank nkn kna',
#  'mor org rga gan ans nst sta tan anl nle ley eyb yba ban ank nkn kna',
#  'mor org rga gan ans nst sta tan anl nle ley eyb yba ban ank nkn kna',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca can ana nad ada dal ali lim imi mit ite ted',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca can ana nad ada dal ali lim imi mit ite ted',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca can ana nad ada dal ali lim imi mit ite ted',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca can ana nad ada dal ali lim imi mit ite ted',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca can ana nad ada dal ali lim imi mit ite ted',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca can ana nad ada dal ali lim imi mit ite ted',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal als lse ser erv rvi vic ice ces esl sll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal als lse ser erv rvi vic ice ces esl sll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal als lse ser erv rvi vic ice ces esl sll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal als lse ser erv rvi vic ice ces esl sll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal als lse ser erv rvi vic ice ces esl sll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal als lse ser erv rvi vic ice ces esl sll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal als lse ser erv rvi vic ice ces esl sll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal als lse ser erv rvi vic ice ces esl sll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal alg lgr gro rou oup upi pin inc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal alg lgr gro rou oup upi pin inc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal al1 l1i 1in inc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal al1 l1i 1in inc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal al1 l1t 1tr tru rus ust st2 t20 201 015 15m 5ms ms1',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal al1 l1t 1tr tru rus ust st2 t20 201 015 15m 5ms ms1',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal al1 l1t 1tr tru rus ust st2 t20 201 015 15m 5ms ms1',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal al1 l1t 1tr tru rus ust st2 t20 201 016 16u 6ub ubs bs1 s11',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal al1 l1t 1tr tru rus ust st2 t20 201 016 16u 6ub ubs bs1 s11',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal al1 l1t 1tr tru rus ust st2 t20 201 016 16u 6ub ubs bs1 s11',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yca cap api pit ita tal al1 l1t 1tr tru rus ust st2 t20 201 017 17h 7h1',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esp spl plc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esp spl plc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esp spl plc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esp spl plc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esp spl plc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esp spl plc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esp spl plc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esp spl plc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esp spl plc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esp spl plc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esp spl plc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esp spl plc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esp spl plc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan anv nve ven ent ntu tur ure res ese sen ene ner erg rgy gyc yco cor orp rpo por ora rat ati tio ion',
#  'jpm pmo mor org rga gan anc nch cha has ase sec eco com omm mme mer erc rci cia ial alm lmo mor ort rtg tga gag age ges ese sec ecu cur uri rit iti tie ies esc sco cor orp',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc',
#  'bla lac ack ckr kro roc ock ckf kfi fin ina nan anc nci cia ial alm lma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc',
#  'jpm pmo mor org rga gan anb nba ban ank nki kir ire rel ela lan and ndp dpl plc',
#  'bla lac ack ckr kro roc ock ckf kfi fin ina nan anc nci cia ial alm lma man ana nag age gem eme men ent nti tin inc',
#  'bla lac ack ckr kro roc ock ckf kfi fin ina nan anc nci cia ial alm lma man ana nag age gem eme men ent nti tin inc',
#  'bla lac ack ckr kro roc ock ckf kfi fin ina nan anc nci cia ial alm lma man ana nag age gem eme men ent nti tin inc',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'com omm mmi min ing ngl gle led edp dpe pen ens nsi sio ion ont ntr tru rus ust stf tfu fun und',
#  'deu eut uts tsc sch che hem emo mor org rga gan ang ngr gre ren enf nfe fel ell llg lgr gro rou oup upp ppu pub ubl bli lic icl cli lim imi mit ite ted edc dco com omp mpa pan any',
#  'deu eut uts tsc sch che hem emo mor org rga gan ang ngr gre ren enf nfe fel ell llg lgr gro rou oup upp ppu pub ubl bli lic icl cli lim imi mit ite ted edc dco com omp mpa pan any',
#  'deu eut uts tsc sch che hem emo mor org rga gan ang ngr gre ren enf nfe fel ell llg lgr gro rou oup upp ppu pub ubl bli lic icl cli lim imi mit ite ted edc dco com omp mpa pan any',
#  'jpm pmo mor org rga gan ana nau aus ust str tra ral ali lia ial ali lim imi mit ite ted',
#  'jpm pmo mor org rga gan anb nba ban ank nkc kca can ana nad ada',
#  'jpm pmo mor org rga gan ane neu eur uro rop ope pel eli lim imi mit ite ted',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esc sca can ana nad ada dai ain inc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ans nse sec ecu cur uri rit iti tie ies esl sll llc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan anc nch cha has ase sec eco com omm mme mer erc rci cia ial alm lmo mor ort rtg tga gag age ges ese sec ecu cur uri rit iti tie ies est str tru rus ust st2 t20 201 015 15u 5ue ues',
#  'jpm pmo mor org rga gan anc nch cha has ase sec eco com omm mme mer erc rci cia ial alm lmo mor ort rtg tga gag age ges ese sec ecu cur uri rit iti tie ies est str tru rus ust st2 t20 201 015 15u 5ue ues',
#  'jpm pmo mor org rga gan anc nch cha has ase sec eco com omm mme mer erc rci cia ial alm lmo mor ort rtg tga gag age ges ese sec ecu cur uri rit iti tie ies est str tru rus ust st2 t20 201 015 15u 5ue ues',
#  'jpm pmo mor org rga gan ane neu eur uro rop ope pel eli lim imi mit ite ted',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco col oll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco col oll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco col oll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco col oll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco col oll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco col oll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco col oll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco col oll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco col oll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'jpm pmo mor org rga gan ani nin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  '111 112 126 26j 6jp jpm pmo mor org rga gan ana nas ass sse set etm tma man ana nag age gem eme men ent nti tin int nte ter ern rna nat ati tio ion ona nal all lli lim imi mit ite ted',
#  '111 112 126 26j 6jp jpm pmo mor org rga gan ana nas ass sse set etm tma man ana nag age gem eme men ent nti tin int nte ter ern rna nat ati tio ion ona nal all lli lim imi mit ite ted',
#  'jpm pmo mor org rga gan ana nau aus ust str tra ral ali lia ial ali lim imi mit ite ted',
#  'jpm pmo mor org rga gan ana nau aus ust str tra ral ali lia ial ali lim imi mit ite ted',
#  'jpm pmo mor org rga gan ana nau aus ust str tra ral ali lia ial ali lim imi mit ite ted',
#  'jpm pmo mor org rga gan ana nau aus ust str tra ral ali lia ial ali lim imi mit ite ted',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco col oll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco col oll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco col oll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco col oll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco col oll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco col oll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco col oll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco col oll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco col oll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco col oll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco col oll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco col oll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco col oll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyj yje jer ers rse sey eyl yli lim imi mit ite ted',
#  'mor org rga gan ans nst sta tan anl nle ley eya yas asi sia ial ali lim imi mit ite ted',
#  'mor org rga gan ans nst sta tan anl nle ley eya yas asi sia ial ali lim imi mit ite ted',
#  'mor org rga gan ans nst sta tan anl nle ley eya yas asi sia ial ali lim imi mit ite ted',
#  'mor org rga gan ans nst sta tan anl nle ley eya yas asi sia ial ali lim imi mit ite ted',
#  'mor org rga gan ans nst sta tan anl nle ley eya yas asi sia ial ali lim imi mit ite ted',
#  'mor org rga gan ans nst sta tan anl nle ley eya yas asi sia ial ali lim imi mit ite ted',
#  'mor org rga gan ans nst sta tan anl nle ley eya yas asi sia ial ali lim imi mit ite ted',
#  'mor org rga gan ans nst sta tan anl nle ley eyi yin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'mor org rga gan ans nst sta tan anl nle ley eyi yin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'mor org rga gan ans nst sta tan anl nle ley eyi yin inv nve ves est stm tme men ent ntm tma man ana nag age gem eme men ent nti tin inc',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco col oll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco col oll llc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc',
#  'mor org rga gan ans nst sta tan anl nle ley eyc yco coi oin int nte ter ern rna nat ati tio ion ona nal alp lpl plc']

# %% [markdown]
# ## Cosine similariy

# %% [markdown]
# #### Making TF matrix (not tf-idf)

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
tf = vectorizer.fit_transform(corpus_ent_targ)

# %% [markdown]
# After applying tf-idf scores I noticed the 'idf' part was giving less weights to tokens that appeared more often in the corpus. In our case this is not what we want. We want all the tokens to be given equal weights as each token represents a chunk of the entity's title. Hence, just tf scoring and not tf-idf scoring is better in this case.

# %% [markdown]
# Now we have a sparse maxtrix of all tokens

# %%
print(tf)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-882cce59488d> in <module>
# ----> 1 breakpoint(tf)
#
# TypeError: set_trace() takes 0 positional arguments but 1 was given

# %%
tf
# Out:
# <440x645 sparse matrix of type '<class 'numpy.int64'>'
# 	with 11683 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Now finding cosine similarity of each entity with every target.`

# %%
# cosine on Tf

similarity_ent_targ = cosine_similarity(tf[0:ent_size], tf[ent_size:])
similarity_ent_targ # List of lists containing each entity and its weights
# Out:
# array([[0.18856181, 0.17153801, 0.14142136, ..., 0.10721125, 0.10721125,
#         0.10721125],
#        [0.18856181, 0.17153801, 0.14142136, ..., 0.10721125, 0.10721125,
#         0.10721125],
#        [0.18856181, 0.17153801, 0.14142136, ..., 0.10721125, 0.10721125,
#         0.10721125],
#        ...,
#        [0.        , 0.        , 0.        , ..., 0.61588176, 0.61588176,
#         0.61588176],
#        [0.        , 0.        , 0.        , ..., 0.61588176, 0.61588176,
#         0.61588176],
#        [0.        , 0.        , 0.        , ..., 0.61588176, 0.61588176,
#         0.61588176]])

# %%
# Index of target with max score for each entry.

targ_indexes = similarity_ent_targ.argmax(axis=1)
targ_indexes #Indexes of targets determined by argmax on cosine similarity weights
# Out:
# array([179, 179, 179, 179, 179, 179, 179, 179, 179, 179,   2,   2,   2,
#          2,   2,   2,   2,   2,   2,   2,   2, 213, 213, 213, 216, 217,
#        218,  18,  98,  31,  31,  18,  18,  18,  18, 227, 227, 227, 218,
#        172,  18,  18,  18,  18,  18,  18,  18,  18,  18,  18,  18,  18,
#         18,  18,  18,  18,  18,  18,  18,  18,  18,  18,  18,  18, 256,
#        256, 256, 256], dtype=int64)

# %%
entities_df = intact_entities_df
targets_df = intact_targets_df
entities_series = entities_df.iloc[:,0]

# %%
# Get targets given indexes

associated_targets = targets_df.iloc[targ_indexes] 
associated_targets_series = associated_targets.iloc[:,0]
associated_targets_series = associated_targets_series.reset_index(drop=False)

# %%
# Concatenating final dataframe

df = pd.concat([entities_series, associated_targets_series], axis=1)

# %% [markdown]
# Creating a csv file

# %%
df.to_csv('C:\\Users\\Ahsan\\Desktop\\Capstone\\Prototype\\matched.csv', index=False)

# %% [markdown]
# ## Output table of matched entities to its target

# %%
df
# Out:
#                                       Random entities  index  \
# 0   JP MORGAN BANK (IRELAND) PLC AS TRUSTEE OF BLA...    179
# 1   JP MORGAN BANK (IRELAND) PLC AS TRUSTEE OF BLA...    179
# 2   JP MORGAN BANK (IRELAND) PLC AS TRUSTEE OF BLA...    179
# 3   JP MORGAN BANK (IRELAND) PLC AS TRUSTEE OF BLA...    179
# 4   JP MORGAN BANK (IRELAND) PLC AS TRUSTEE OF BLA...    179
# 5   JP MORGAN BANK (IRELAND) PLC AS TRUSTEE OF BLA...    179
# 6   JP MORGAN BANK (IRELAND) PLC AS TRUSTEE OF BLA...    179
# 7   JP MORGAN BANK (IRELAND) PLC AS TRUSTEE OF BLA...    179
# 8   JP MORGAN BANK (IRELAND) PLC AS TRUSTEE OF BLA...    179
# 9   JP MORGAN BANK (IRELAND) PLC AS TRUSTEE OF BLA...    179
# 10  COMMINGLED PENSION TRUST FUND (INTERMEDIATE PU...      2
# 11  COMMINGLED PENSION TRUST FUND (INTERNATIONAL E...      2
# 12  Commingled Pension Trust Fund (Large Cap Growt...      2
# 13  COMMINGLED PENSION TRUST FUND (PUBLIC BOND) OF...      2
# 14  Commingled Pension Trust Fund (Stable Asset In...      2
# 15  COMMINGLED PENSION TRUST FUND (STABLE INCOME B...      2
# 16  COMMINGLED PENSION TRUST FUND (SYSTEMATIC ALPH...      2
# 17  Commingled Pension Trust Fund (U.S. Active Cor...      2
# 18  Commingled Pension Trust Fund (U.S. Active Val...      2
# 19  COMMINGLED PENSION TRUST FUND (U.S. REAL ESTAT...      2
# 20  Commingled Pension Trust Fund (U.S. Smartlndex...      2
# 21                     DEUTSCHE MORGAN GREN AUS L-SYD    213
# 22  DEUTSCHE MORGAN GRENFELL (C.I.) LIMITED FKA: M...    213
# 23             DEUTSCHE MORGAN GRENFELL AUSTRALIA LTD    213
# 24                           J P MORGAN AUST LTD MELB    216
# 25                          J P MORGAN CANADA-TOR ONT    217
# 26                          J P MORGAN EUROPE LTD LDN    218
# 27                          J P MORGAN INV MGT INC-NY     18
# 28                         J P MORGAN SEC CAN INC-TOR     98
# 29                          J P Morgan Securities LLC     31
# ..                                                ...    ...
# 38                         J.P. MORGAN EUROPE LIMITED    218
# 39  J.P. MORGAN EXCHANGE-TRADED FUND - JPMORGAN CO...    172
# 40                J.P. MORGAN INV MGT AAF SEL FD(USA)     18
# 41                            J.P. MORGAN INV MGT-USA     18
# 42              J.P. MORGAN INVESTMENT MANAGEMENT CO.     18
# 43             J.P. MORGAN INVESTMENT MANAGEMENT INC.     18
# 44             J.P. MORGAN INVESTMENT MANAGEMENT INC.     18
# 45  J.P. MORGAN INVESTMENT MANAGEMENT INC. AS AGEN...     18
# 46  J.P. Morgan Investment Management Inc. As Agen...     18
# 47  J.P. MORGAN INVESTMENT MANAGEMENT INC. AS AGEN...     18
# 48                        J.P. MORGAN INVESTMENT MGMT     18
# 49                        J.P. MORGAN INVESTMENT MGMT     18
# 50                        J.P. MORGAN INVESTMENT MGMT     18
# 51                        J.P. MORGAN INVESTMENT MGMT     18
# 52                        J.P. MORGAN INVESTMENT MGMT     18
# 53                        J.P. MORGAN INVESTMENT MGMT     18
# 54                        J.P. MORGAN INVESTMENT MGMT     18
# 55                        J.P. MORGAN INVESTMENT MGMT     18
# 56                        J.P. MORGAN INVESTMENT MGMT     18
# 57                     J.P. MORGAN INVESTMENT MGMT IN     18
# 58                     J.P. MORGAN INVESTMENT MGMT IN     18
# 59                     J.P. MORGAN INVESTMENT MGMT IN     18
# 60                     J.P. MORGAN INVESTMENT MGMT IN     18
# 61                     J.P. MORGAN INVESTMENT MGMT IN     18
# 62                     J.P. MORGAN INVESTMENT MGMT IN     18
# 63                         J.P. MORGAN INVST MGMT-NYC     18
# 64                                     MORGAN STANLEY    256
# 65                                     MORGAN STANLEY    256
# 66                                     MORGAN STANLEY    256
# 67                                     MORGAN STANLEY    256
#
#                                                Target
# 0                      J.P. Morgan Bank (Ireland) plc
# 1                      J.P. Morgan Bank (Ireland) plc
# 2                      J.P. Morgan Bank (Ireland) plc
# 3                      J.P. Morgan Bank (Ireland) plc
# 4                      J.P. Morgan Bank (Ireland) plc
# 5                      J.P. Morgan Bank (Ireland) plc
# 6                      J.P. Morgan Bank (Ireland) plc
# 7                      J.P. Morgan Bank (Ireland) plc
# 8                      J.P. Morgan Bank (Ireland) plc
# 9                      J.P. Morgan Bank (Ireland) plc
# 10                      Commingled Pension Trust Fund
# 11                      Commingled Pension Trust Fund
# 12                      Commingled Pension Trust Fund
# 13                      Commingled Pension Trust Fund
# 14                      Commingled Pension Trust Fund
# 15                      Commingled Pension Trust Fund
# 16                      Commingled Pension Trust Fund
# 17                      Commingled Pension Trust Fund
# 18                      Commingled Pension Trust Fund
# 19                      Commingled Pension Trust Fund
# 20                      Commingled Pension Trust Fund
# 21  Deutsche Morgan Grenfell Group Public Limited ...
# 22  Deutsche Morgan Grenfell Group Public Limited ...
# 23  Deutsche Morgan Grenfell Group Public Limited ...
# 24                      J.P. Morgan Australia Limited
# 25                            J.P. Morgan Bank Canada
# 26                         J.P. Morgan Europe Limited
# 27            J.P. Morgan Investment Management, Inc.
# 28                  J.P. Morgan Securities Canada Inc
# 29                         J.P. Morgan Securities LLC
# ..                                                ...
# 38                         J.P. Morgan Europe Limited
# 39            J.P. Morgan Ventures Energy Corporation
# 40            J.P. Morgan Investment Management, Inc.
# 41            J.P. Morgan Investment Management, Inc.
# 42            J.P. Morgan Investment Management, Inc.
# 43            J.P. Morgan Investment Management, Inc.
# 44            J.P. Morgan Investment Management, Inc.
# 45            J.P. Morgan Investment Management, Inc.
# 46            J.P. Morgan Investment Management, Inc.
# 47            J.P. Morgan Investment Management, Inc.
# 48            J.P. Morgan Investment Management, Inc.
# 49            J.P. Morgan Investment Management, Inc.
# 50            J.P. Morgan Investment Management, Inc.
# 51            J.P. Morgan Investment Management, Inc.
# 52            J.P. Morgan Investment Management, Inc.
# 53            J.P. Morgan Investment Management, Inc.
# 54            J.P. Morgan Investment Management, Inc.
# 55            J.P. Morgan Investment Management, Inc.
# 56            J.P. Morgan Investment Management, Inc.
# 57            J.P. Morgan Investment Management, Inc.
# 58            J.P. Morgan Investment Management, Inc.
# 59            J.P. Morgan Investment Management, Inc.
# 60            J.P. Morgan Investment Management, Inc.
# 61            J.P. Morgan Investment Management, Inc.
# 62            J.P. Morgan Investment Management, Inc.
# 63            J.P. Morgan Investment Management, Inc.
# 64                                     Morgan Stanley
# 65                                     Morgan Stanley
# 66                                     Morgan Stanley
# 67                                     Morgan Stanley
#
# [68 rows x 3 columns]
